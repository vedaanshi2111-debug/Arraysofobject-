# %% [markdown]
# <a href="https://colab.research.google.com/github/vedaanshi2111-debug/Arraysofobject-/blob/main/st_bioinfo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
# !pip install qiskit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# !pip install qiskit

# %%
# !pip install pylatexenc --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=07e63b22cbdcccdff048dae092ec020394f6d5e7b082a177481af461a62c6569
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %%
x = [0.3, 0.8] #Defines two classical input features to encode into the qubits.
qc = QuantumCircuit(2) #Creates a quantum circuit with 2 qubits.
qc.ry(np.pi * x[0], 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-140936795.py in <cell line: 0>()
#       1 x = [0.3, 0.8] #Defines two classical input features to encode into the qubits.
# ----> 2 qc = QuantumCircuit(2) #Creates a quantum circuit with 2 qubits.
#       3 qc.ry(np.pi * x[0], 0)
#
# NameError: name 'QuantumCircuit' is not defined

# %%
# Quantum Feature Encoding (Angle Encoding)
#Encodes classical data into qubits using rotation angles.
#Each feature turns into a quantum rotation → quantum representation of data.
# !pip install qiskit qiskit[visualization] qiskit_aer #Installs Qiskit 2.2.3, IBM’s quantum programming framework.
#Installs the visualization extras (for circuit diagrams, Bloch spheres, histograms).
#Installs Qiskit Aer, a fast quantum simulator.
#Installs pylatexenc, a necessary library for LaTeX-based figure rendering.
# !pip install pylatexenc --upgrade #Installs/updates pylatexenc needed for some Qiskit visualization features.
# Imports the QuantumCircuit class for building quantum circuits.
from qiskit import QuantumCircuit
import numpy as np #Imports NumPy for numerical calculations like rotation angles.
# Example circuit
x = [0.3, 0.8] #Defines two classical input features to encode into the qubits.
qc = QuantumCircuit(2) #Creates a quantum circuit with 2 qubits.
qc.ry(np.pi * x[0], 0) #Encodes the first feature by rotating qubit 0 around the Y-axis.
#An ry rotation in quantum computing is a single-qubit gate that rotates the qubit's state by a specified angle around the Y-axis of the Bloch sphere.
#It is a fundamental operation for manipulating qubits with precision and is defined by a unitary matrix with cosine and sine entries.
#The angle of rotation, \(\theta \), must be specified in radians.
qc.ry(np.pi * x[1], 1) #Encodes the second feature by rotating qubit 1 around the Y-axis.
# Draw circuit
qc.draw("text") #Displays the circuit in text format
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 82.9 MB/s eta 0:00:00
# ...
#      ┌───────────┐
# q_0: ┤ Ry(3π/10) ├
#      └┬──────────┤
# q_1: ─┤ Ry(4π/5) ├
#       └──────────┘

# %%
# Install Qiskit and Aer
# !pip install qiskit qiskit-aer

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_bloch_multivector

qc = QuantumCircuit(1)
qc.h(0)
qc.save_statevector()
state = AerSimulator(method='statevector').run(qc).result().get_statevector()
plot_bloch_multivector(state)

# %%
# Install Qiskit
# !pip install qiskit

# Import required modules
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# Create a simple circuit to generate a state
qc = QuantumCircuit(1)
qc.h(0)  # Put qubit into superposition

# Simulate the statevector
simulator = Aer.get_backend('statevector_simulator')
result = simulator.run(qc).result()
statevector = result.get_statevector(qc)

# Visualize on Bloch sphere
plot_bloch_multivector(statevector)
plt.show()

# %%
# !pip install qiskit qiskit-aer

# %%
# Install Qiskit and Aer (ensure they are available)
# !pip install qiskit qiskit-aer

import matplotlib.pyplot as plt
from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector

# Create a simple circuit
qc = QuantumCircuit(1)
qc.h(0)

# Simulate statevector
sim = Aer.get_backend('statevector_simulator')
result = sim.run(qc).result()   # Use run() instead of execute()
statevector = result.get_statevector(qc)

# Visualize Bloch sphere
plot_bloch_multivector(statevector)
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 80.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 104.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 75.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# Install Qiskit and Aer
# !pip install qiskit qiskit-aer

from qiskit import QuantumCircuit
from qiskit_aer import Aer
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# Create a simple circuit
qc = QuantumCircuit(1)
qc.h(0)

# Simulate statevector
sim = Aer.get_backend('statevector_simulator')
result = sim.run(qc).result()   # use run() instead of execute()
statevector = result.get_statevector(qc)

# Visualize Bloch sphere
plot_bloch_multivector(statevector)
plt.show()

# %%
#Visualizing Quantum Data States (Bloch Sphere)
#Shows how quantum data looks on a Bloch sphere → great for teaching superposition.
from qiskit import QuantumCircuit              # Import QuantumCircuit to build quantum circuits
from qiskit_aer import AerSimulator            # Import AerSimulator to simulate circuits
from qiskit.visualization import plot_bloch_multivector  # Import function to plot Bloch sphere
# Create a quantum circuit with 1 qubit
qc = QuantumCircuit(1)
# Apply a Hadamard gate to qubit 0
# This creates an equal superposition state: (|0> + |1>)/sqrt(2)
qc.h(0)
# Instruct the simulator to save the final quantum statevector of this circuit
qc.save_statevector()
# Initialize a statevector simulator and run the circuit
# Then extract the resulting statevector of the 1-qubit system
state = AerSimulator(method='statevector').run(qc).result().get_statevector()
# Plot the statevector on the Bloch sphere to visualize the qubit's state
plot_bloch_multivector(state)

# %%
#Simple Entanglement-Based Feature Transformation
#Entanglement creates non-linear feature mixing, useful in QML for learning complex patterns.
from qiskit import QuantumCircuit   # Import QuantumCircuit class from Qiskit
# Create a quantum circuit with 2 qubits (qubit 0 and qubit 1)
qc = QuantumCircuit(2)
# Apply a Ry rotation of angle 0.6 radians to qubit 0
# This puts qubit 0 into a superposition depending on the angle 0.6
qc.ry(0.6, 0)
# Apply a CNOT gate with:
# - control qubit = 0
# - target qubit = 1
# This entangles qubit 1 with qubit 0 based on the state of qubit 0
qc.cx(0, 1)
# Draw the circuit using matplotlib-based visualization
qc.draw("mpl")
